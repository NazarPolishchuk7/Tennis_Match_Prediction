# %%
import pandas as pd
import numpy as np

# %%
pip install psycopg2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2

# %%
connect = psycopg2.connect(
    host = 'localhost',
    database ='atp',
    user = 'postgres',
    password = '12345678'

)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:12345678@localhost:5432/atp')

# %%
def select(sql):
    return pd.read_sql_query(sql,engine)

# %%
sql = 'SELECT * FROM atp_matches_2004'

# %%
select(sql)
# Out:
#      tourney_id    tourney_name surface  draw_size tourney_level  \
# 0     2004-1536  Madrid Masters    Hard         48             M
# 1     2004-1536  Madrid Masters    Hard         48             M
# 2     2004-1536  Madrid Masters    Hard         48             M
# 3     2004-1536  Madrid Masters    Hard         48             M
# 4     2004-1536  Madrid Masters    Hard         48             M
# ...         ...             ...     ...        ...           ...
# 3283   2004-615      Dusseldorf    Clay         64             A
# 3284   2004-615      Dusseldorf    Clay         64             A
# 3285   2004-615      Dusseldorf    Clay         64             A
# 3286   2004-615      Dusseldorf    Clay         64             A
# 3287   2004-615      Dusseldorf    Clay         64             A
#
#       tourney_date  match_num  winner_id  winner_seed winner_entry  ...  \
# 0         20041018          1     102610          NaN         None  ...
# ...

# %%
#for creating a simple model we are using matches from 2010 to 2022

# %%
sql = 'SELECT * FROM atp_matches_2010'

# %%
select(sql)
# Out:
#      tourney_id                tourney_name surface  draw_size tourney_level  \
# 0      2010-339                    Brisbane    Hard         32             A
# 1      2010-339                    Brisbane    Hard         32             A
# 2      2010-339                    Brisbane    Hard         32             A
# 3      2010-339                    Brisbane    Hard         32             A
# 4      2010-339                    Brisbane    Hard         32             A
# ...         ...                         ...     ...        ...           ...
# 3025  2010-D045  Davis Cup WG F: SRB vs FRA    Hard          4             D
# 3026  2010-D045  Davis Cup WG F: SRB vs FRA    Hard          4             D
# 3027   2010-615                  Dusseldorf    Clay         32             A
# 3028   2010-615                  Dusseldorf    Clay         32             A
# 3029   2010-615                  Dusseldorf    Clay         32             A
#
# ...

# %%
list_matches = []

# %%
for i in range(2010,2023):
    sql = f'SELECT * FROM atp_matches_{i}'
    list_matches.append(select(sql))

# %%
len(list_matches)
# Out:
# 13

# %%
df = pd.concat(list_matches)

# %%
df
# Out:
#                             tourney_id                  tourney_name surface  \
# 0                             2010-339                      Brisbane    Hard
# 1                             2010-339                      Brisbane    Hard
# 2                             2010-339                      Brisbane    Hard
# 3                             2010-339                      Brisbane    Hard
# 4                             2010-339                      Brisbane    Hard
# ...                                ...                           ...     ...
# 2912  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 2913  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 2914  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
# 2915  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
# 2916  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
#
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                              tourney_id                  tourney_name surface  \
# 0                              2010-339                      Brisbane    Hard
# 1                              2010-339                      Brisbane    Hard
# 2                              2010-339                      Brisbane    Hard
# 3                              2010-339                      Brisbane    Hard
# 4                              2010-339                      Brisbane    Hard
# ...                                 ...                           ...     ...
# 36504  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 36505  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 36506  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
# 36507  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
# 36508  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
#
# ...

# %%
df.shape
# Out:
# (36509, 49)

# %%
df.to_csv('C:/Users/nazar/Tennis_Match_Prediction/data/processed_data/data_2010_to_2022.csv', index=False)

# %%
pd.read_csv('C:/Users/nazar/Tennis_Match_Prediction/data/processed_data/data_2010_to_2022.csv')
# Out:
#                              tourney_id                  tourney_name surface  \
# 0                              2010-339                      Brisbane    Hard
# 1                              2010-339                      Brisbane    Hard
# 2                              2010-339                      Brisbane    Hard
# 3                              2010-339                      Brisbane    Hard
# 4                              2010-339                      Brisbane    Hard
# ...                                 ...                           ...     ...
# 36504  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 36505  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 36506  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
# 36507  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
# 36508  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
#
# ...

# %%
df
# Out:
#                              tourney_id                  tourney_name surface  \
# 0                              2010-339                      Brisbane    Hard
# 1                              2010-339                      Brisbane    Hard
# 2                              2010-339                      Brisbane    Hard
# 3                              2010-339                      Brisbane    Hard
# 4                              2010-339                      Brisbane    Hard
# ...                                 ...                           ...     ...
# 36504  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 36505  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 36506  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
# 36507  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
# 36508  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
#
# ...

# %%
df.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points'],
#       dtype='object')

# %%
len(df['winner_id'].unique())
# Out:
# 973

# %%
len(df['loser_id'].unique())
# Out:
# 1423

# %%
sql = 'SELECT * FROM atp_players'
players =select(sql)

# %%
players.head()
# Out:
#    player_id name_first name_last hand         dob  ioc  height wikidata_id
# 0     100001    Gardnar    Mulloy    R  19131122.0  USA   185.0      Q54544
# 1     100002     Pancho    Segura    R  19210620.0  ECU   168.0      Q54581
# 2     100003      Frank   Sedgman    R  19271002.0  AUS   180.0     Q962049
# 3     100004   Giuseppe     Merlo    R  19271011.0  ITA     NaN    Q1258752
# 4     100005    Richard  Gonzalez    R  19280509.0  USA   188.0      Q53554

# %%
df['player_id'] = players[players['players_id']]
